# %%
pwd
# Out:
# '/Users/peterwilliams/Desktop/learning/python'

# %%
# importing the pandas library
import pandas as pd
# reading in csv files in python
df = pd.read_csv('pokemon_data.csv')

# if the file was an excel file you can run the following code
# df = pd.read_excel('pokemon_data.xlsx')

# if it is a tsv or txt file, you can read it in like this:
# df = pd.read_csv('pokemon_data.csv', delimiter="\t")

# %%
# seeing the first 5 rows of the data
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# quickly viewing info about data:

# how to read the colnames:
df.columns

# how to read individual columns:
df['Name'][1:5] # the first bracket names the column, the second calls the number of items to show (if all the items are wanted leave the second bracket blank)
# to read more than one column:
# print(df[['Name', 'Type 1', 'HP']]) # because this is a list inside of a call, there needs to be double brackets

# read each row:
df.iloc[1]

# for info on more than one row:
# print(df.iloc[0:4])

# to read a specific location:
# print(df.iloc[2,1]) # this will print the second column and the first item

# to iterate through each row and find the index:
# for index, row in df.iterrows():
# print(index, row['Name']) # if we wanted to iterate eveything in each row, we wouldn't call the first column name.
    
# To filter based on a single row:
df.loc[df["Type 1"]=="Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
# describing the data frame:
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# sorting the data:
# df.sort_values('Name') # ascending by alphabetical

# df.sort_values('Name', ascending = False) 3 descending sort

# multiple sorts
# df.sort_values(['Type 1', 'HP'], ascending=[1,0]) # 1 = True, 0 = False
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-2724b70e52cb> in <module>
#       7 # df.sort_values(['Type 1', 'HP'], ascending=[1,0]) # 1 = True, 0 = False
#       8
# ----> 9 df.sort_values(['Legendary'] == True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: False

# %%
# Making changes to the data: Mutating columns



# df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
# we can create a new column by defining it the way we did above
# df.head()

# a different way to do the same thing
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head()


# rearranging the columns:
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head()

# removing the new total column
# df = df.drop(columns=['Total'])

# df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
